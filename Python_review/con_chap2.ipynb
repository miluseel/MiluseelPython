# %%
#input()함수로 사용자 입력받기

string = input("인사말을 입력하세요>")

# %%
#사용자가 입력한 내용이 input함수 결과로 나옴
#이 값은 다른 변수에 대입하여 사용 가능

string = input("인사말을 입력하세요>")
print(string)
# Out:
# 하윙

# %%
#input()함수의 입력 자료형
#input()함수는 사용자가 무엇을 입력해도 결과는 무조건 문자열
#number에 대입한 12345도 str으로 확인됨 + t/f (boolean값)
print(type(string))

number = input("숫자를 입력하세요>")
print(number)

print(type(number))
# Out:
# <class 'str'>
# 12345
# <class 'str'>

# %%
#직접 해보는 손코딩

#1-1.
#입력을 받습니다.
string = input("입력>")

#출력합니다.
print("자료:", string)
print("자료형:",type(string))

#1-2.
#입력을 받습니다.
string = input("입력>")

#출력합니다.
print("자료:", string)
print("자료형:",type(string))
# Out:
# 자료: 12121
# 자료형: <class 'str'>
# 자료: true
# 자료형: <class 'str'>

# %%
#직접 해보는 손코딩

#입력을 받습니다.
string = input("입력>")

#출력합니다.
print("입력 + 100:", string + 100)

#input()함수로 자료를 입력 받은 후 입력받은 것과 숫자를 더하는 코드를 작성하면 문제 발생함
#문자열은 문자열끼리, 숫자는 숫자끼리 연산 !
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 7
#       4 string = input("입력>")
#       6 #출력합니다.
# ----> 7 print("입력 + 100:", string + 100)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#Q.문자열을 숫자를 바꾸기

#캐스트 : 문자형을 숫자형으로 변환
#input()함수의 입력자료형은 항상 문자열 -> 숫자로 변환해서 숫자연산에 활용가능

#int()함수 :문자열을 int자료형으로 변환 (정수형)
#float()함수 : 문자열을 float자료형으로 변환 (실수형, 부동소수점)

#직접해보는 손코딩 : int()

string_a=input("입력A>")
int_a = int(string_a)

string_b = input("입력B>")
int_b = int(string_b)

print("문자열 자료 : ", string_a + string_b)
print("숫자 자료:", int_a + int_b)
# Out:
# 문자열 자료 :  27352
# 숫자 자료: 325

# %%
#손코딩_input()함수와 float()함수 활용하기

output_a = int("52")
output_b = float("52.273")

print(type(output_a),output_a)
print(type(output_b),output_b)
# Out:
# <class 'int'> 52
# <class 'float'> 52.273

# %%
#int()함수와 float()함수 조합하기

input_a = float(input("첫 번째 숫자>"))
input_b = float(input("두 번째 숫자>"))

print("덧셈 결과:", input_a + input_b)
print("뺼셈 결과:", input_a - input_b)
print("곱셈 결과:", input_a * input_b)
print("나눗셈 결과:", input_a / input_b)
# Out:
# 덧셈 결과: 325.0
# 뺼셈 결과: 221.0
# 곱셈 결과: 14196.0
# 나눗셈 결과: 5.25

# %%
#valueError 예외

#1.숫자가 아닌 것을 숫자로 변환하려고 할 때
#2. 소수점이 있는 숫자형식의 문자열을 int()함수로 변환하려고 할 때
#구분이 어려울 경우 일단, float()함수를 사용하면 됨_float는 정수, 실수 구분없으니까

# %%
#숫자를 문자열로 바꾸기 _ str(), format()

#str(다른 자료형) : 문자열로 변환

#손코딩_str()함수를 사용해 숫자를 문자열로 변환하기
output_a = str(52)
output_b = str(52.273)
print(type(output_a), output_a)
print(type(output_b), output_b)
# Out:
# <class 'str'> 52
# <class 'str'> 52.273

# %%
#inch단위를 cm단위로 변경하기

#손코딩_inch단위를 cm단위로 변경

#숫자를 입력받습니다.
raw_input=input("inch단위의 숫자를 입력해주세요")
inch = int(raw_input)
cm = inch * 2.54

#출력합니다.
print(inch, "inch는 cm단위로", cm, "cm입니다.")
# Out:
# 27 inch는 cm단위로 68.58 cm입니다.

# %%
#숫자와 문자열의 다양한 기능

#문자열의 format()
#"{}".format(10)
#"{}{}".format(10,20)
#"{}{}{}{}{}".format(101,202,303,404,505)

#손코딩_format()함수로 숫자를 문자열로 변환하기

#format()함수로 숫자를 문자열로 변환하기
string_a = "{}".format(10)

#출력하기
print(string_a)
print(type(string_a))
# Out:
# 10
# <class 'str'>

# %%
#손코딩 format()함수의 다양한 형태

#format()함수로 숫자를 문자열로 변환하기
format_a="{}만원".format(5000)
format_b ="파이썬 열공하여 첫 연봉 {}만원 만들기".format(5000)
format_c="{}{}{}".format(3000,4000,5000)
format_d="{}{}{}".format(1,"문자열",True)

#출력하기
print(format_a)
print(format_b)
print(format_c)
print(format_d)

#{}기호 앞뒤로 다른 문자열을 넣어 표현을 다르게 할 수 있음
#format()함수는 숫자 이외의 자료형에도 적용할 수 있음
# Out:
# 5000만원
# 파이썬 열공하여 첫 연봉 5000만원 만들기
# 300040005000
# 1문자열True

# %%
#indexError예외
#{}기호의 개수가 format()함수의 매개변수 개수보다 많으면 indexError예외 발생

"{}{}".format(1,2,3,4,5)
"{}{}{}".format(1,2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 5
#       1 #indexError예외
#       2 #{}기호의 개수가 format()함수의 매개변수 개수보다 많으면 indexError예외 발생
#       4 "{}{}".format(1,2,3,4,5)
# ----> 5 "{}{}{}".format(1,2)
#
# IndexError: Replacement index 2 out of range for positional args tuple

# %%
#format()함수의 다양한 기능
#{:d} :int 자료형의 정수를 출력하겠다고 직접적으로 지정 _ 매개변수로 정수만 올 수 있음
#{:5d} : 5칸을 빈 칸으로 잡고 뒤에서부터 52라는 숫자를 채움
#{:05d} : 5칸을 잡고 뒤에서부터 52라는 숫자를 넣은 후 , 앞의 빈 곳을 0으로 채움
#부호가 있을 떄는 맨 앞자리를 부호로 채우고 나머지 빈 곳을 0으로 채움

#손코딩_ 정수를 특정 칸에 출력하기
output_a = "{:d}".format(52)

#특정 칸에 출력하기
output_b="{:5d}".format(52) #5칸
output_c="{:10d}".format(52) #10칸

#빈칸을 0으로 채우기
output_d ="{:05d}".format(52) #양수
output_e = "{:05d}".format(-52) #음수

print("#기본")
print(output_a)
print("#특정 칸에 출력하기")
print(output_b)
print(output_c)
print("#빈칸을 0으로 채우기")
print(output_d)
print(output_e)
# Out:
# #기본
# 52
# #특정 칸에 출력하기
#    52
#         52
# #빈칸을 0으로 채우기
# 00052
# -0052

# %%
#손코딩_기호붙여 출력하기

#기호를 함께 출력하기
output_f = "{:+d}".format(52) #양수
output_g = "{:+d}".format(-52) #음수
output_h = "{: d}".format(52) #양수: 기호부분 공백
output_i = "{: d}".format(-52) #음수: 기호부분 공백

print("#기호와 함께 출력하기")
print(output_f)
print(output_g)
print(output_h)
print(output_i)
# Out:
# #기호와 함께 출력하기
# +52
# -52
#  52
# -52

# %%
#손코딩_조합해보기

#조합하기
output_h = "{:+5d}".format(52)
output_i = "{:+5d}".format(-52)
output_j = "{:=+5d}".format(52)
output_k = "{:=+5d}".format(-52)
output_l = "{:+05d}".format(52)
output_m = "{:+05d}".format(-52)

print("#조합하기")
print(output_h)
print(output_i)
print(output_j)
print(output_k)
print(output_l)
print(output_m)
# Out:
# #조합하기
#   +52
#   -52
# +  52
# -  52
# +0052
# -0052

# %%
# 부동소수점 출력의 다양한 형태
# 소수점이 들어가는 float자료형 숫자 : {:f}

# 손코딩 _ 다양한 형태의 부동 소수점 출력하기
output_a = "{:f}".format(52.273)
output_b="{:15f}".format(52.273) #15칸 만들기
output_c= "{:+15f}".format(52.273) #15칸에 부호 추가하기
output_d="{:+015f}".format(52.273) #15칸에 부호 추가하고 0으로 채우기

print(output_a)
print(output_b)
print(output_c)
print(output_d)
# Out:
# 52.273000
#       52.273000
#      +52.273000
# +0000052.273000

# %%
#부동 소수점의 경우 소수점 아래 자릿수 지정 가능 

#손코딩_소수점 아래 자릿수 지정하기
output_a = "{:15.3f}".format(52.273)
output_b = "{:15.2f}".format(52.273)
output_c = "{:15.1f}".format(52.273)

print(output_a)
print(output_b)
print(output_c)

#15칸을 잡고 소수점을 각각 3자리, 2자리, 1자리로 출력 + 자동으로 반올림
# Out:
#          52.273
#           52.27
#            52.3

# %%
#의미없는 소수점 제거하기 : {:g}
#0과 0.0을 출력했을 떄 내부적으로 자료형이 달라 서로 다른 값 출력

#손코딩_의미없는 소수점 제거하기
output_a = 52.0
output_b = "{:g}".format(output_a)

print(output_a)
print(output_b)
# Out:
# 52.0
# 52

# %%
#대소문자 바꾸기 :upper(), lower()
#원본을 변화시키지 않는 비파괴적 함수 <-> 파괴적 함수

a="Hello Python Programming...!"
a.upper()
# Out:
# 'HELLO PYTHON PROGRAMMING...!'

# %%
a="Hello Python Programming...!"
a.lower()
# Out:
# 'hello python programming...!'

# %%
#문자열 양옆의 공백 제거하기 _ 띄어쓰기, 탭, 줄바꿈 모두 포함 
#양쪽 공백 제거 : strip()
#왼쪽 공백 제거 : lstrip()
#오른쪽 공백 제거 : rstrip()

input_a="""
    안녕하세요
문자열의 함수를 알아봅시다.
"""
print(input_a.strip())

#줄바꿈과 띄어쓰기는 들어갔지만, 공백 제거 이후에 모두 사라짐
# Out:
# 안녕하세요
# 문자열의 함수를 알아봅시다.

# %%
#문자열의 구성 파악하기 : isOO()
#문자열이 소문자로만 구성되어 있는지, 알파벳으로만 구성되어 있는지, 숫자로만 구성되어 있는지 등을 확인

#isalnum():문자열이 알파벳 또는 숫자로만 구성되어 있는지 확인
#isalpha(): 문자열이 알파벳으로만 구성되어 있는지 확인
#isidentifier(): 문자열이 식별자로 사용할 수 있는 것인지 확인
#isdecimal(): 정수형태인지 확인
#isdigit(): 숫자로 인식될 수 있는 것인지 확인
#isspace(): 공백으로만 구성되어 있는지 확인
#islower():소문자로만 구성되어 있는지 확인
#isupper(): 대문자로만 구성되어 있는지 확인

print("TrainA10".isalnum())
print("10".isdigit())
# Out:
# True
# True

# %%
#문자열 찾기 :find()와 rfind()
#문자열 내부에 특정문자가 어디에 위치하는지 확인할 때 
#find(): 왼쪽부터 찾아서 처음 등장하는 위치 찾음 
#rfind():오른쪽 부터 찾아서 처음 등장하는 위치 찾음
#문자열 가장 앞글자는 0 !

output_a = "안녕안녕하세요".find("안녕")
print(output_a)

output_b = "안녕안녕하세요".rfind("안녕")
print(output_b)
# Out:
# 0
# 2

# %%
#문자열과 in연산자 : 문자열 내부에 어떤 문자열이 있는지 확인할 때
#T/F로 출력

print("안녕"in "안녕하세요")
print("잘자" in "안녕하세요")
# Out:
# True
# False

# %%
#문자열 자르기: split()

a="10 20 30 40 50".split(" ")
print(a)

#공백을 기준으로 자름
#실행결과로 리스트가 나옴
# Out:
# ['10', '20', '30', '40', '50']

# %%
#f-문자열 vs format()
#f'문자열{표현식}문자열'
#대부분 f'문자열을 사용

#format() 사용이 더 좋은경우
#1.문자열 내용이 너무 많을 때
#2.데이터를 리스트에 담아서 사용할 때

"{}".format(10)
# Out:
# '10'

# %%
f'{10}'
# Out:
# '10'

# %%
f"3+4= {3+4}"
# Out:
# '3+4= 7'

# %%
#예제 확인

string="hello"

string.upper()
print("a지점",string)
# Out:
# a지점 hello
